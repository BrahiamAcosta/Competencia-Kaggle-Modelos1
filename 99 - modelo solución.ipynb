# %% [markdown]
# <a href="https://colab.research.google.com/github/BrahiamAcosta/Competencia-Kaggle-Modelos1/blob/main/99%20-%20modelo%20soluci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Carga de datos

# %%
import pandas as pd
import os

os.environ["KAGGLE_CONFIG_DIR"] = "."


# !kaggle competitions download -c udea-ai4eng-20242
# !unzip udea-ai4eng-20242.zip
# !rm udea-ai4eng-20242.zip
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 ./kaggle.json'
# Downloading udea-ai4eng-20242.zip to /content
#  84% 17.0M/20.1M [00:00<00:00, 71.9MB/s]
# 100% 20.1M/20.1M [00:00<00:00, 65.6MB/s]
# Archive:  udea-ai4eng-20242.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# ##Limpieza preliminar de los datos
#
# Se mapearán manualmente a una forma categórica las columnas que tienen un orden intrinseco. Con las demás se aplicará la tecnica de encoding por medio de un targetEncoding suavizado, con el que busca determinar el peso de las otras columnas sobre la variable objetivo

# %%
# !pip install category_encoders
# !pip install catboost
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.16.0)
# Downloading category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.4
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.0 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
#Cleaning dataset function
def clean_dataset(df):
  matricula = {
    'No pagó matrícula': 0,
    'Menos de 500 mil': 1,
    'Entre 500 mil y menos de 1 millón': 2,
    'Entre 1 millón y menos de 2.5 millones': 3,
    'Entre 2.5 millones y menos de 4 millones': 4,
    'Entre 4 millones y menos de 5.5 millones': 5,
    'Entre 5.5 millones y menos de 7 millones': 6,
    'Más de 7 millones': 7
  }
  estratos_vivienda = {
      'Estrato 1': 1,
      'Estrato 2': 2,
      'Estrato 3': 3,
      'Estrato 4': 4,
      'Estrato 5': 5,
      'Estrato 6': 6,
      'Sin Estrato': 0
  }
  educacion_padres = {
      'Ninguno': 1,
      'Primaria incompleta': 2,
      'Primaria completa': 3,
      'Secundaria (Bachillerato) incompleta': 4,
      'Secundaria (Bachillerato) completa': 5,
      'Técnica o tecnológica incompleta': 6,
      'Técnica o tecnológica completa': 7,
      'Educación profesional incompleta': 8,
      'Educación profesional completa': 9,
      'Postgrado': 10,
      'No sabe': 0,
      'No Aplica': -1,
  }
  internet = {
      'Si': 1,
      'No': 0
  }
  pago_matricula = {
      'Si': 1,
      'No': 0
  }
  trabaja ={
      '0':0,
      'Menos de 10 horas':1,
      'Entre 11 y 20 horas':2,
      'Entre 21 y 30 horas':3,
      'Más de 30 horas':4
  }
  if 'RENDIMIENTO_GLOBAL' in df.columns:
    df['RENDIMIENTO_GLOBAL'] = df['RENDIMIENTO_GLOBAL'].map({"bajo":1, "medio-bajo":2, "medio-alto":3, "alto":4})
  df['ESTU_VALORMATRICULAUNIVERSIDAD'] = df['ESTU_VALORMATRICULAUNIVERSIDAD'].map(matricula)
  df['ESTU_VALORMATRICULAUNIVERSIDAD'] = df['ESTU_VALORMATRICULAUNIVERSIDAD'].fillna(-1)
  df['FAMI_ESTRATOVIVIENDA'] = df['FAMI_ESTRATOVIVIENDA'].map(estratos_vivienda)
  df['FAMI_ESTRATOVIVIENDA'] = df['FAMI_ESTRATOVIVIENDA'].fillna(-1)
  df.FAMI_EDUCACIONMADRE = df.FAMI_EDUCACIONMADRE.map(educacion_padres)
  df.FAMI_EDUCACIONPADRE = df.FAMI_EDUCACIONPADRE.map(educacion_padres)
  df.FAMI_EDUCACIONMADRE = df.FAMI_EDUCACIONMADRE.fillna(-1)
  df.FAMI_EDUCACIONPADRE = df.FAMI_EDUCACIONPADRE.fillna(-1)
  df.FAMI_TIENEINTERNET = df.FAMI_TIENEINTERNET.map(internet)
  df.FAMI_TIENEINTERNET = df.FAMI_TIENEINTERNET.fillna(-1)
  df.ESTU_PAGOMATRICULAPROPIO = df.ESTU_PAGOMATRICULAPROPIO.map(pago_matricula)
  df.ESTU_PAGOMATRICULAPROPIO = df.ESTU_PAGOMATRICULAPROPIO.fillna(-1)
  df.ESTU_HORASSEMANATRABAJA = df.ESTU_HORASSEMANATRABAJA.map(trabaja)
  df.ESTU_HORASSEMANATRABAJA = df.ESTU_HORASSEMANATRABAJA.fillna(-1)

  return df

# %%
dtr = pd.read_csv("train.csv")
del(dtr['ID'])
dtr.head()
# Out:
#    PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0    20212                  ENFERMERIA                 BOGOTÁ
# 1    20212                     DERECHO              ATLANTICO
# 2    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# 0            Estrato 3                 Si    Técnica o tecnológica incompleta
# 1            Estrato 3                 No      Técnica o tecnológica completa
# 2            Estrato 3                 Si  Secundaria (Bachillerato) completa
# 3            Estrato 4                 Si                             No sabe
# 4            Estrato 3                 Si                   Primaria completa
#
#                   FAMI_EDUCACIONMADRE ESTU_PAGOMATRICULAPROPIO  \
# 0                           Postgrado                       No
# 1    Técnica o tecnológica incompleta                       No
# 2  Secundaria (Bachillerato) completa                       No
# 3  Secundaria (Bachillerato) completa                       No
# 4                   Primaria completa                       No
#
#   RENDIMIENTO_GLOBAL
# 0         medio-alto
# 1               bajo
# 2               bajo
# 3               alto
# 4         medio-bajo

# %%
dtr = clean_dataset(dtr)
dtr.head()
# Out:
#    PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0    20212                  ENFERMERIA                 BOGOTÁ
# 1    20212                     DERECHO              ATLANTICO
# 2    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4    20212                  PSICOLOGIA              ANTIOQUIA
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                             6.0                      1.0
# 1                             4.0                      0.0
# 2                             4.0                      4.0
# 3                             5.0                      0.0
# 4                             4.0                      3.0
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                   3.0                 1.0                  6.0
# 1                   3.0                 0.0                  7.0
# 2                   3.0                 1.0                  5.0
# 3                   4.0                 1.0                  0.0
# 4                   3.0                 1.0                  3.0
#
#    FAMI_EDUCACIONMADRE  ESTU_PAGOMATRICULAPROPIO  RENDIMIENTO_GLOBAL
# 0                 10.0                       0.0                   3
# 1                  6.0                       0.0                   1
# 2                  5.0                       0.0                   1
# 3                  5.0                       0.0                   4
# 4                  3.0                       0.0                   2

# %% [markdown]
# ###Configuración del Encoder:
#
# Como mencioné un poco más arriba, hare uso del encoder MEstimateEncoder para pasar a un valor numérico las columnas que no tienen un orden aparente, que en este caso son: La carrera del estudiante, El departamento donde estudia, y el Periodo en el que presentó las pruebas.

# %%
#Encoder
from category_encoders import MEstimateEncoder as ME
cols_to_encode = ['PERIODO',	'ESTU_PRGM_ACADEMICO'	,'ESTU_PRGM_DEPARTAMENTO']
encoder = ME(m=40)
encoder.fit(dtr[cols_to_encode].astype(str), dtr['RENDIMIENTO_GLOBAL'])

def transform_data(df,transformer=encoder):
  df_encoded = encoder.transform(df[cols_to_encode].astype(str))
  df_final = pd.concat([df_encoded,df.drop(cols_to_encode, axis=1)],axis=1)
  return df_final

# %%
dtr = transform_data(dtr)
dtr.head()
# Out:
#     PERIODO  ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0  2.394607             2.314279                2.557373
# 1  2.394607             2.629367                2.454827
# 2  2.584049             2.480372                2.557373
# 3  2.458686             2.298972                2.733969
# 4  2.394607             2.466352                2.667522
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                             6.0                      1.0
# 1                             4.0                      0.0
# 2                             4.0                      4.0
# 3                             5.0                      0.0
# 4                             4.0                      3.0
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                   3.0                 1.0                  6.0
# 1                   3.0                 0.0                  7.0
# 2                   3.0                 1.0                  5.0
# 3                   4.0                 1.0                  0.0
# 4                   3.0                 1.0                  3.0
#
#    FAMI_EDUCACIONMADRE  ESTU_PAGOMATRICULAPROPIO  RENDIMIENTO_GLOBAL
# 0                 10.0                       0.0                   3
# 1                  6.0                       0.0                   1
# 2                  5.0                       0.0                   1
# 3                  5.0                       0.0                   4
# 4                  3.0                       0.0                   2

# %% [markdown]
# Ahora que todo nuestro dataset está en formato numérico, podemos pasar a la plantilla de modelo

# %%
X = dtr.drop("RENDIMIENTO_GLOBAL", axis=1)
y = dtr.RENDIMIENTO_GLOBAL

# %% [markdown]
# ##CatboostClassifier:
#
# Este es un modelo enfocado en problemas de clasificación, donde la variable objetivo se compone de más de dos categorías bien diferenciadas.

# %%
#Modelo CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score, KFold, train_test_split, RandomizedSearchCV

z=CatBoostClassifier(
    iterations=500
)

z.fit(X,y)
# Out:
# Learning rate set to 0.198406
# 0:	learn: 1.3409635	total: 422ms	remaining: 3m 30s
# 1:	learn: 1.3135553	total: 781ms	remaining: 3m 14s
# 2:	learn: 1.2934919	total: 1.12s	remaining: 3m 5s
# 3:	learn: 1.2781852	total: 1.48s	remaining: 3m 3s
# 4:	learn: 1.2675226	total: 1.81s	remaining: 2m 59s
# 5:	learn: 1.2591117	total: 2.19s	remaining: 2m 59s
# 6:	learn: 1.2523081	total: 2.53s	remaining: 2m 58s
# 7:	learn: 1.2469831	total: 2.89s	remaining: 2m 57s
# 8:	learn: 1.2421410	total: 3.22s	remaining: 2m 55s
# 9:	learn: 1.2381647	total: 3.57s	remaining: 2m 54s
# 10:	learn: 1.2349293	total: 3.91s	remaining: 2m 53s
# 11:	learn: 1.2323102	total: 4.29s	remaining: 2m 54s
# 12:	learn: 1.2303441	total: 4.6s	remaining: 2m 52s
# 13:	learn: 1.2284166	total: 4.92s	remaining: 2m 50s
# 14:	learn: 1.2266211	total: 5.26s	remaining: 2m 50s
# 15:	learn: 1.2252021	total: 5.6s	remaining: 2m 49s
# 16:	learn: 1.2240305	total: 5.93s	remaining: 2m 48s
# 17:	learn: 1.2227737	total: 6.29s	remaining: 2m 48s
# 18:	learn: 1.2218657	total: 6.61s	remaining: 2m 47s
# 19:	learn: 1.2203391	total: 6.95s	remaining: 2m 46s
# 20:	learn: 1.2195972	total: 7.28s	remaining: 2m 46s
# 21:	learn: 1.2186657	total: 7.63s	remaining: 2m 45s
# 22:	learn: 1.2179600	total: 7.93s	remaining: 2m 44s
# 23:	learn: 1.2174841	total: 8.26s	remaining: 2m 43s
# 290:	learn: 1.1861521	total: 1m 53s	remaining: 1m 21s
# 291:	learn: 1.1861217	total: 1m 54s	remaining: 1m 21s
# 292:	learn: 1.1860770	total: 1m 54s	remaining: 1m 21s
# 293:	learn: 1.1860434	total: 1m 55s	remaining: 1m 20s
# 294:	learn: 1.1859950	total: 1m 56s	remaining: 1m 20s
# 295:	learn: 1.1859488	total: 1m 56s	remaining: 1m 20s
# 296:	learn: 1.1858858	total: 1m 57s	remaining: 1m 20s
# 297:	learn: 1.1858465	total: 1m 57s	remaining: 1m 19s
# 298:	learn: 1.1858128	total: 1m 58s	remaining: 1m 19s
# 299:	learn: 1.1857634	total: 1m 59s	remaining: 1m 19s
# 300:	learn: 1.1857044	total: 1m 59s	remaining: 1m 18s
# 301:	learn: 1.1856589	total: 1m 59s	remaining: 1m 18s
# 302:	learn: 1.1856210	total: 2m	remaining: 1m 18s
# 303:	learn: 1.1855555	total: 2m	remaining: 1m 17s
# 304:	learn: 1.1855090	total: 2m	remaining: 1m 17s
# 305:	learn: 1.1854846	total: 2m 1s	remaining: 1m 16s
# 306:	learn: 1.1854500	total: 2m 1s	remaining: 1m 16s
# 307:	learn: 1.1854118	total: 2m 1s	remaining: 1m 15s
# 308:	learn: 1.1853794	total: 2m 2s	remaining: 1m 15s
# 309:	learn: 1.1853228	total: 2m 2s	remaining: 1m 15s
# 310:	learn: 1.1852917	total: 2m 2s	remaining: 1m 14s
# 311:	learn: 1.1852652	total: 2m 3s	remaining: 1m 14s
# 312:	learn: 1.1851955	total: 2m 3s	remaining: 1m 13s
# 313:	learn: 1.1851491	total: 2m 3s	remaining: 1m 13s
# 314:	learn: 1.1851113	total: 2m 4s	remaining: 1m 12s
# 315:	learn: 1.1850346	total: 2m 4s	remaining: 1m 12s
# 316:	learn: 1.1849131	total: 2m 4s	remaining: 1m 12s
# 317:	learn: 1.1848670	total: 2m 5s	remaining: 1m 11s
# 318:	learn: 1.1848300	total: 2m 5s	remaining: 1m 11s
# 319:	learn: 1.1847999	total: 2m 5s	remaining: 1m 10s
# 320:	learn: 1.1847471	total: 2m 6s	remaining: 1m 10s
# 321:	learn: 1.1846775	total: 2m 6s	remaining: 1m 9s
# 322:	learn: 1.1845887	total: 2m 6s	remaining: 1m 9s
# 323:	learn: 1.1845521	total: 2m 7s	remaining: 1m 9s
# 324:	learn: 1.1845215	total: 2m 7s	remaining: 1m 8s
# 325:	learn: 1.1844851	total: 2m 7s	remaining: 1m 8s
# 326:	learn: 1.1844371	total: 2m 8s	remaining: 1m 7s
# 327:	learn: 1.1843799	total: 2m 8s	remaining: 1m 7s
# 328:	learn: 1.1843183	total: 2m 8s	remaining: 1m 7s
# 329:	learn: 1.1842294	total: 2m 9s	remaining: 1m 6s
# 330:	learn: 1.1841825	total: 2m 10s	remaining: 1m 6s
# 331:	learn: 1.1841538	total: 2m 10s	remaining: 1m 6s
# 332:	learn: 1.1841243	total: 2m 11s	remaining: 1m 5s
# 469:	learn: 1.1791623	total: 3m 4s	remaining: 11.8s
# 470:	learn: 1.1791334	total: 3m 5s	remaining: 11.4s
# 471:	learn: 1.1790891	total: 3m 5s	remaining: 11s
# 472:	learn: 1.1790397	total: 3m 6s	remaining: 10.6s
# 473:	learn: 1.1790114	total: 3m 6s	remaining: 10.2s
# 474:	learn: 1.1789801	total: 3m 6s	remaining: 9.82s
# 475:	learn: 1.1789501	total: 3m 7s	remaining: 9.43s
# 476:	learn: 1.1789228	total: 3m 7s	remaining: 9.04s
# 477:	learn: 1.1788915	total: 3m 7s	remaining: 8.64s
# 478:	learn: 1.1788624	total: 3m 8s	remaining: 8.25s
# 479:	learn: 1.1788286	total: 3m 8s	remaining: 7.86s
# 480:	learn: 1.1787948	total: 3m 9s	remaining: 7.48s
# 481:	learn: 1.1787667	total: 3m 9s	remaining: 7.09s
# 482:	learn: 1.1787260	total: 3m 10s	remaining: 6.71s
# 483:	learn: 1.1786966	total: 3m 11s	remaining: 6.32s
# 484:	learn: 1.1786558	total: 3m 11s	remaining: 5.93s
# 485:	learn: 1.1786289	total: 3m 12s	remaining: 5.54s
# 486:	learn: 1.1785811	total: 3m 12s	remaining: 5.15s
# 487:	learn: 1.1785558	total: 3m 13s	remaining: 4.75s
# 488:	learn: 1.1785136	total: 3m 13s	remaining: 4.35s
# 489:	learn: 1.1785018	total: 3m 13s	remaining: 3.96s
# 490:	learn: 1.1784864	total: 3m 14s	remaining: 3.56s
# 491:	learn: 1.1784641	total: 3m 14s	remaining: 3.16s
# 492:	learn: 1.1784298	total: 3m 14s	remaining: 2.77s
# 493:	learn: 1.1783959	total: 3m 15s	remaining: 2.37s
# 494:	learn: 1.1783646	total: 3m 15s	remaining: 1.98s
# 495:	learn: 1.1783425	total: 3m 15s	remaining: 1.58s
# 496:	learn: 1.1783089	total: 3m 16s	remaining: 1.18s
# 497:	learn: 1.1782823	total: 3m 16s	remaining: 789ms
# 498:	learn: 1.1782525	total: 3m 16s	remaining: 395ms
# 499:	learn: 1.1782277	total: 3m 17s	remaining: 0us

# %%
dts = pd.read_csv('test.csv')
Xts = dts.copy()
del(Xts['Unnamed: 0'])
del(Xts['ID'])
Xts.head()
# Out:
#    PERIODO                     ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0    20183                          TRABAJO SOCIAL                BOLIVAR
# 1    20203  ADMINISTRACION COMERCIAL Y DE MERCADEO              ANTIOQUIA
# 2    20212                  INGENIERIA MECATRONICA                 BOGOTÁ
# 3    20195                      CONTADURIA PUBLICA                  SUCRE
# 4    20212              ADMINISTRACION DE EMPRESAS              ATLANTICO
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0                          Menos de 500 mil       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
# 2    Entre 1 millón y menos de 2.5 millones                       0
# 3    Entre 1 millón y menos de 2.5 millones     Entre 21 y 30 horas
# 4  Entre 2.5 millones y menos de 4 millones     Entre 11 y 20 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 0            Estrato 3                 Si
# 1            Estrato 2                 Si
# 2            Estrato 3                 Si
# 3            Estrato 1                 No
# 4            Estrato 2                 Si
#
#                     FAMI_EDUCACIONPADRE                 FAMI_EDUCACIONMADRE  \
# 0        Técnica o tecnológica completa                   Primaria completa
# 1    Secundaria (Bachillerato) completa      Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) incompleta  Secundaria (Bachillerato) completa
# 3                   Primaria incompleta                 Primaria incompleta
# 4    Secundaria (Bachillerato) completa  Secundaria (Bachillerato) completa
#
#   ESTU_PAGOMATRICULAPROPIO
# 0                       Si
# 1                       No
# 2                       No
# 3                       No
# 4                       No

# %%
Xts = clean_dataset(Xts)
Xts.head()
# Out:
#    PERIODO                     ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0    20183                          TRABAJO SOCIAL                BOLIVAR
# 1    20203  ADMINISTRACION COMERCIAL Y DE MERCADEO              ANTIOQUIA
# 2    20212                  INGENIERIA MECATRONICA                 BOGOTÁ
# 3    20195                      CONTADURIA PUBLICA                  SUCRE
# 4    20212              ADMINISTRACION DE EMPRESAS              ATLANTICO
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                             1.0                      1.0
# 1                             4.0                      3.0
# 2                             3.0                      0.0
# 3                             3.0                      3.0
# 4                             4.0                      2.0
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                   3.0                 1.0                  7.0
# 1                   2.0                 1.0                  5.0
# 2                   3.0                 1.0                  4.0
# 3                   1.0                 0.0                  2.0
# 4                   2.0                 1.0                  5.0
#
#    FAMI_EDUCACIONMADRE  ESTU_PAGOMATRICULAPROPIO
# 0                  3.0                       1.0
# 1                  7.0                       0.0
# 2                  5.0                       0.0
# 3                  2.0                       0.0
# 4                  5.0                       0.0

# %%
Xts = transform_data(Xts)
Xts.head()
# Out:
#     PERIODO  ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0  2.577201             2.011725                2.282220
# 1  2.584049             2.193516                2.667522
# 2  2.394607             3.083426                2.557373
# 3  2.458686             2.194167                1.975351
# 4  2.394607             2.298972                2.454827
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                             1.0                      1.0
# 1                             4.0                      3.0
# 2                             3.0                      0.0
# 3                             3.0                      3.0
# 4                             4.0                      2.0
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                   3.0                 1.0                  7.0
# 1                   2.0                 1.0                  5.0
# 2                   3.0                 1.0                  4.0
# 3                   1.0                 0.0                  2.0
# 4                   2.0                 1.0                  5.0
#
#    FAMI_EDUCACIONMADRE  ESTU_PAGOMATRICULAPROPIO
# 0                  3.0                       1.0
# 1                  7.0                       0.0
# 2                  5.0                       0.0
# 3                  2.0                       0.0
# 4                  5.0                       0.0

# %%
preds = z.predict(Xts)
preds = preds.flatten()
preds
# Out:
# array([1, 3, 4, ..., 3, 4, 4])

# %%
preds = pd.Series(preds,name='RENDIMIENTO_GLOBAL')
preds = preds.map({1: "bajo", 2: "medio-bajo", 3: "medio-alto", 4: "alto"})
preds
# Out:
# 0               bajo
# 1         medio-alto
# 2               alto
# 3               bajo
# 4               bajo
#              ...
# 296781    medio-bajo
# 296782          alto
# 296783    medio-alto
# 296784          alto
# 296785          alto
# Name: RENDIMIENTO_GLOBAL, Length: 296786, dtype: object

# %%
#csv de prediccion
submission = pd.DataFrame([dts.ID,preds]).T
submission.head()
# Out:
#        ID RENDIMIENTO_GLOBAL
# 0  550236               bajo
# 1   98545         medio-alto
# 2  499179               alto
# 3  782980               bajo
# 4  785185               bajo

# %%
submission.to_csv('submission.csv',index=False)
